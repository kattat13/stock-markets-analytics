# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
parquet_path = '/content/drive/MyDrive/stocks_df_combined_trunc_2014_2023.parquet.brotli'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_parquet(parquet_path)

# %%
df.tail()
# Out:
#              Open         High          Low        Close  Adj Close_x  \
# 5338  3424.000000  3496.000000  3408.600098  3477.949951  3477.949951
# 5339  3477.949951  3508.350098  3477.949951  3490.050049  3490.050049
# 5340  3510.000000  3549.000000  3504.149902  3544.000000  3544.000000
# 5341  3545.000000  3559.949951  3500.500000  3518.050049  3518.050049
# 5342  3531.000000  3540.000000  3495.000000  3526.000000  3526.000000
#
#          Volume Ticker  Year      Month  Weekday  ... growth_brent_oil_7d  \
# 5338  1681707.0  LT.NS  2023 2023-12-01        4  ...            1.064772
# 5339  1072263.0  LT.NS  2023 2023-12-01        1  ...            1.058217
# 5340  1389266.0  LT.NS  2023 2023-12-01        2  ...            1.040496
# 5341  3371121.0  LT.NS  2023 2023-12-01        3  ...            1.005645
# 5342   968577.0  LT.NS  2023 2023-12-01        4  ...            0.972359
#
#       growth_brent_oil_30d  growth_brent_oil_90d  growth_brent_oil_365d  \
# ...

# %%
df.columns.to_list()
# Out:
# ['Open',
#  'High',
#  'Low',
#  'Close',
#  'Adj Close_x',
#  'Volume',
#  'Ticker',
#  'Year',
#  'Month',
#  'Weekday',
#  'Date',
#  'growth_1d',
#  'growth_3d',
#  'growth_7d',
#  'growth_30d',
#  'growth_90d',
#  'growth_365d',
#  'growth_future_5d',
#  'SMA10',
#  'SMA20',
#  'growing_moving_average',
#  'high_minus_low_relative',
#  'volatility',
#  'is_positive_growth_5d_future',
#  'ticker_type',
#  'index_x',
#  'adx',
#  'adxr',
#  'apo',
#  'aroon_1',
#  'aroon_2',
#  'aroonosc',
#  'bop',
#  'cci',
#  'cmo',
#  'dx',
#  'macd',
#  'macdsignal',
#  'macdhist',
#  'macd_ext',
#  'macdsignal_ext',
#  'macdhist_ext',
#  'macd_fix',
#  'macdsignal_fix',
#  'macdhist_fix',
#  'mfi',
#  'minus_di',
#  'mom',
#  'plus_di',
#  'dm',
#  'ppo',
#  'roc',
#  'rocp',
#  'rocr',
#  'rocr100',
#  'rsi',
#  'slowk',
#  'slowd',
#  'fastk',
#  'fastd',
#  'fastk_rsi',
#  'fastd_rsi',
#  'trix',
#  'ultosc',
#  'willr',
#  'index_y',
#  'ad',
#  'adosc',
#  'obv',
#  'atr',
#  'natr',
# ...

# %%
over_200 = df[df['cci'] >= 200]
# let's not forget we trade only on Fridays
over_200 = over_200[over_200['Weekday'] == 4]

# %%
# filtering out because we only need some columns
over_200 = over_200[['Adj Close_x', 	'Ticker', 	'Year', 	'Month', 	'Weekday', 	'Date', 'growth_future_5d']]

# %%
over_200
# Out:
#       Adj Close_x Ticker  Year      Month  Weekday       Date  \
# 7113    34.912762   MSFT  2014 2014-05-01        4 2014-05-30
# 7181    39.395618   MSFT  2014 2014-09-01        4 2014-09-05
# 7340    41.630741   MSFT  2015 2015-04-01        4 2015-04-24
# 7452    40.151123   MSFT  2015 2015-10-01        4 2015-10-02
# 7467    46.583046   MSFT  2015 2015-10-01        4 2015-10-23
# ...           ...    ...   ...        ...      ...        ...
# 5072  2058.108887  LT.NS  2022 2022-11-01        4 2022-11-25
# 5219  2469.979980  LT.NS  2023 2023-06-01        4 2023-06-30
# 5234  2580.430908  LT.NS  2023 2023-07-01        4 2023-07-21
# 5268  2901.600098  LT.NS  2023 2023-09-01        4 2023-09-08
# 5323  3190.649902  LT.NS  2023 2023-12-01        4 2023-12-01
#
#       growth_future_5d
# 7113          1.013190
# 7181          1.017207
# 7340          1.016503
# 7452          1.033794
# 7467          0.995650
# ...                ...
# 5072          1.011029
# 5219          0.989417
# ...

# %%
over_200['profit'] = 1000 * over_200['growth_future_5d'] - 1000
over_200
# Out:
#       Adj Close_x Ticker  Year      Month  Weekday       Date  \
# 7113    34.912762   MSFT  2014 2014-05-01        4 2014-05-30
# 7181    39.395618   MSFT  2014 2014-09-01        4 2014-09-05
# 7340    41.630741   MSFT  2015 2015-04-01        4 2015-04-24
# 7452    40.151123   MSFT  2015 2015-10-01        4 2015-10-02
# 7467    46.583046   MSFT  2015 2015-10-01        4 2015-10-23
# ...           ...    ...   ...        ...      ...        ...
# 5072  2058.108887  LT.NS  2022 2022-11-01        4 2022-11-25
# 5219  2469.979980  LT.NS  2023 2023-06-01        4 2023-06-30
# 5234  2580.430908  LT.NS  2023 2023-07-01        4 2023-07-21
# 5268  2901.600098  LT.NS  2023 2023-09-01        4 2023-09-08
# 5323  3190.649902  LT.NS  2023 2023-12-01        4 2023-12-01
#
#       growth_future_5d     profit
# 7113          1.013190  13.190094
# 7181          1.017207  17.207263
# 7340          1.016503  16.503151
# 7452          1.033794  33.793947
# 7467          0.995650  -4.350092
# ...

# %%
over_200['profit'].sum()
# Out:
# 1048.262891817731

# %%
over_200['growth_future_5d'].sum() / 100
# Out:
# 4.601629540060662
